# %%
#OUTPUT FOR DIABETES.CSV
import pandas
from keras.models import Sequential
from keras.layers import Dense, Activation

from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

dataset = pd.read_csv("diabetes.csv", header=None).values

X_train, X_test, Y_train, Y_test = train_test_split(dataset[:,0:8], dataset[:,8],
                                                    test_size=0.25, random_state=87)
np.random.seed(155)
my_first_nn = Sequential()
my_first_nn.add(Dense(20, input_dim=8, activation='relu'))
my_first_nn.add(Dense(1, activation='sigmoid'))
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100,
                                     initial_epoch=0)
print(my_first_nn.summary())
print(my_first_nn.evaluate(X_test, Y_test))
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - acc: 0.3641 - loss: 32.5524
# Epoch 2/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.3612 - loss: 17.1609
# Epoch 3/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.5620 - loss: 6.1862
# Epoch 4/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6550 - loss: 3.1546
# Epoch 5/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6168 - loss: 2.4731
# Epoch 6/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6453 - loss: 2.0742
# Epoch 7/100
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - acc: 0.6257 - loss: 1.4316
# Epoch 8/100
# ...

# %%
#ADDING MORE DENSE LAYER TO THE EXISTING CODE
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

dataset = pd.read_csv("diabetes.csv", header=None).values

X_train, X_test, Y_train, Y_test = train_test_split(dataset[:, 0:8], dataset[:, 8], test_size=0.25, random_state=87)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

my_first_nn = Sequential()

my_first_nn.add(Dense(20, input_dim=8, activation='relu'))

my_first_nn.add(Dense(40, activation='relu'))
my_first_nn.add(Dense(60, activation='relu'))
my_first_nn.add(Dense(80, activation='relu'))


my_first_nn.add(Dense(1, activation='sigmoid'))


my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])


my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, validation_split=0.2)


print(my_first_nn.summary())

test_loss, test_accuracy = my_first_nn.evaluate(X_test, Y_test)
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6746 - loss: 0.6727 - val_accuracy: 0.6466 - val_loss: 0.6213
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6782 - loss: 0.5965 - val_accuracy: 0.6379 - val_loss: 0.5692
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6629 - loss: 0.5630 - val_accuracy: 0.6810 - val_loss: 0.5322
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7496 - loss: 0.4955 - val_accuracy: 0.7500 - val_loss: 0.5209
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7543 - loss: 0.4607 - val_accuracy: 0.7328 - val_loss: 0.5197
# ...

# %%
#OUTPUT FOR BREASTCANCER.CSV
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

dataset = pd.read_csv("breastcancer.csv", header=None).values


X = dataset[1:, 2:32]
Y = dataset[1:, 1]


label_encoder = LabelEncoder()
Y = label_encoder.fit_transform(Y)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=87)

# Normalize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Build the model with more Dense layers
my_first_nn = Sequential()

# Add first hidden layer, adjust input_dim to match the number of features (30)
my_first_nn.add(Dense(20, input_dim=30, activation='relu')) # Changed input_dim to 30

# Add more Dense layers
my_first_nn.add(Dense(40, activation='relu'))
my_first_nn.add(Dense(60, activation='relu'))
my_first_nn.add(Dense(80, activation='relu'))
my_first_nn.add(Dense(100, activation='relu'))

# Output layer
my_first_nn.add(Dense(1, activation='sigmoid'))

# Compile the model
my_first_nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
my_first_nn_fitted = my_first_nn.fit(X_train, Y_train, epochs=100, validation_split=0.2)

# Model summary
print(my_first_nn.summary())

# Evaluate the model
test_loss, test_accuracy = my_first_nn.evaluate(X_test, Y_test)
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7256 - loss: 0.6360 - val_accuracy: 0.8953 - val_loss: 0.4799
# Epoch 2/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9040 - loss: 0.4098 - val_accuracy: 0.9535 - val_loss: 0.2228
# Epoch 3/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9384 - loss: 0.2103 - val_accuracy: 0.9651 - val_loss: 0.1133
# Epoch 4/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9583 - loss: 0.1116 - val_accuracy: 0.9651 - val_loss: 0.0906
# Epoch 5/100
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9743 - loss: 0.0663 - val_accuracy: 0.9302 - val_loss: 0.1223
# ...

# %%
#Plotting the loss and accuracy for both training data and validation data using the history object in the source code

import matplotlib.pyplot as plt

# Assuming you have already trained your model and have the 'history' object from model.fit()
# Example: history = model.fit(...)

# Plotting the loss for training and validation
plt.figure(figsize=(12, 6))

# Plot the loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot the accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()

# %%
#Plot one of the images in the test data, and then do inferencing to check what is the prediction of the model on the single image

import numpy as np
import matplotlib.pyplot as plt

# Assuming that you have already trained your model and the history is available
# Also assuming x_test is scaled and reshaped already as needed for the model

# Step 1: Plot one image from the test dataset
image_index = 0  # You can change this index to plot a different image
plt.imshow(x_test[image_index], cmap='gray')  # Display the test image
plt.title(f"True Label: {y_test[image_index]}")  # Display the true label
plt.show()

# Step 2: Preprocess the image
# Reshape the image to match the input shape of the model (28, 28, 1)
image = x_test[image_index].reshape(1, 28, 28, 1).astype('float32') / 255  # Normalize the image

# Step 3: Perform inference (prediction) on the image
prediction = model.predict(image)

# Step 4: Get the predicted label
predicted_label = np.argmax(prediction)  # Get the class with the highest probability

# Display the prediction
print(f"Predicted Label: {predicted_label}")
print(f"True Label: {y_test[image_index]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# Predicted Label: 7
# True Label: 7

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.utils import to_categorical

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Normalize the images (scaling pixel values between 0 and 1)
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Reshape the data to fit the model input shape (28x28 images flattened into 1D)
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# Convert labels to one-hot encoding
y_train_one_hot = to_categorical(y_train, 10)
y_test_one_hot = to_categorical(y_test, 10)

# Build the model with more hidden layers and different activation functions
model = Sequential()

# Flatten the input images (28x28x1 -> 784)
model.add(Flatten(input_shape=(28, 28)))

# Add hidden layers with `tanh` activation function
# Modify the number of neurons and hidden layers to experiment

# First hidden layer with `tanh` activation
model.add(Dense(128, activation='tanh'))

# Second hidden layer with `tanh` activation
model.add(Dense(64, activation='tanh'))

# Third hidden layer (optional, for more complexity) with `tanh` activation
model.add(Dense(32, activation='tanh'))

# Output layer (softmax for multi-class classification)
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train_one_hot, epochs=10, batch_size=128, validation_data=(x_test, y_test_one_hot))

# Plot the loss and accuracy for both training and validation data
plt.figure(figsize=(12, 6))

# Plot the loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs (Modified Model with Tanh)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot the accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs (Modified Model with Tanh)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8316 - loss: 0.6282 - val_accuracy: 0.9449 - val_loss: 0.1894
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9514 - loss: 0.1700 - val_accuracy: 0.9606 - val_loss: 0.1313
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9680 - loss: 0.1088 - val_accuracy: 0.9681 - val_loss: 0.1077
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9757 - loss: 0.0816 - val_accuracy: 0.9709 - val_loss: 0.0940
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9830 - loss: 0.0594 - val_accuracy: 0.9710 - val_loss: 0.0941
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.9851 - loss: 0.0479 - val_accuracy: 0.9733 - val_loss: 0.0852
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9892 - loss: 0.0361 - val_accuracy: 0.9726 - val_loss: 0.0846
# Epoch 8/10
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.utils import to_categorical

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# No scaling: Keep the raw pixel values as they are (integers between 0 and 255)
# We won't normalize the pixel values in this case

# Reshape the data to fit the model input shape (28x28 images flattened into 1D)
x_train = x_train.reshape(x_train.shape[0], 28, 28, 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1)

# Convert labels to one-hot encoding
y_train_one_hot = to_categorical(y_train, 10)
y_test_one_hot = to_categorical(y_test, 10)

# Build the model with more hidden layers and different activation functions
model = Sequential()

# Flatten the input images (28x28x1 -> 784)
model.add(Flatten(input_shape=(28, 28)))

# Add hidden layers with `tanh` activation function
# Modify the number of neurons and hidden layers to experiment

# First hidden layer with `tanh` activation
model.add(Dense(128, activation='tanh'))

# Second hidden layer with `tanh` activation
model.add(Dense(64, activation='tanh'))

# Third hidden layer (optional, for more complexity) with `tanh` activation
model.add(Dense(32, activation='tanh'))

# Output layer (softmax for multi-class classification)
model.add(Dense(10, activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(x_train, y_train_one_hot, epochs=10, batch_size=128, validation_data=(x_test, y_test_one_hot))

# Plot the loss and accuracy for both training and validation data
plt.figure(figsize=(12, 6))

# Plot the loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Over Epochs (Raw Pixel Values)')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plot the accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Over Epochs (Raw Pixel Values)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.7171 - loss: 0.9343 - val_accuracy: 0.8666 - val_loss: 0.4381
# Epoch 2/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8737 - loss: 0.4046 - val_accuracy: 0.9018 - val_loss: 0.3123
# Epoch 3/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.8908 - loss: 0.3458 - val_accuracy: 0.8987 - val_loss: 0.3275
# Epoch 4/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8997 - loss: 0.3200 - val_accuracy: 0.9041 - val_loss: 0.3067
# Epoch 5/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.9065 - loss: 0.3001 - val_accuracy: 0.9121 - val_loss: 0.2834
# Epoch 6/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9087 - loss: 0.2933 - val_accuracy: 0.9083 - val_loss: 0.2927
# Epoch 7/10
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9157 - loss: 0.2709 - val_accuracy: 0.9159 - val_loss: 0.2755
# Epoch 8/10
# ...
